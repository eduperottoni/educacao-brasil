# %% [markdown]
# <a href="https://colab.research.google.com/github/eduperottoni/educacao-brasil/blob/main/aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aula 03

# %%
import pandas as pd

fonte = "https://github.com/alura-cursos/imersao-dados-2-2020/blob/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv?raw=true"

dados = pd.read_csv(fonte)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_LC")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True)

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="density", cumulative=True)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data = dados_sem_notas_zero, x="NU_NOTA_MT", y="NU_NOTA_LC", hue="Q025")
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
provas
# Out:
# ['NU_NOTA_CN',
#  'NU_NOTA_CH',
#  'NU_NOTA_MT',
#  'NU_NOTA_LC',
#  'NU_NOTA_REDACAO',
#  'NU_NOTA_TOTAL']

# %%
sns.pairplot(dados_sem_notas_zero[provas])

# %%
correlacao = dados_sem_notas_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_REDACAO  NU_NOTA_TOTAL
# NU_NOTA_CN         1.000000    0.668979  ...         0.504740       0.785600
# NU_NOTA_CH         0.668979    1.000000  ...         0.528338       0.735534
# NU_NOTA_MT         0.649527    0.610332  ...         0.493046       0.790051
# NU_NOTA_LC         0.641624    0.744170  ...         0.535797       0.711686
# NU_NOTA_REDACAO    0.504740    0.528338  ...         1.000000       0.783647
# NU_NOTA_TOTAL      0.785600    0.735534  ...         0.783647       1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True)

# %% [markdown]
# Desafio 01: Desafio: Plotar as médias, medianas e moda nas notas de LC e MT (matiplotlib linha vertical)

# %%
provas = ["NU_NOTA_CN","NU_NOTA_CH","NU_NOTA_MT","NU_NOTA_LC","NU_NOTA_REDACAO"]

dados["NU_NOTA_TOTAL"] = dados[provas].sum(axis=1)
dados.head()

dados_sem_notas_zero = dados.query("NU_NOTA_TOTAL != 0")
dados_sem_notas_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))
media = dados_sem_notas_zero['NU_NOTA_MT'].mean()
moda = dados_sem_notas_zero['NU_NOTA_MT'].mode()[0]
mediana = dados_sem_notas_zero['NU_NOTA_MT'].median()
ax = sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")
plt.axvline(media, c='r') 
plt.axvline(moda, c='g') 
plt.axvline(mediana, c='b') 
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(12,8))
media = dados_sem_notas_zero['NU_NOTA_LC'].mean()
moda = dados_sem_notas_zero['NU_NOTA_LC'].mode()[0]
mediana = dados_sem_notas_zero['NU_NOTA_LC'].median()
ax = sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_LC")
plt.axvline(media, c='r') 
plt.axvline(moda, c='g') 
plt.axvline(mediana, c='b') 
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Desafio 02: Melhorar a visualização da matriz de correlação e analisar mais detalhadamente.

# %%
correlacao = dados_sem_notas_zero[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_LC  NU_NOTA_REDACAO
# NU_NOTA_CN         1.000000    0.668979  ...    0.641624         0.504740
# NU_NOTA_CH         0.668979    1.000000  ...    0.744170         0.528338
# NU_NOTA_MT         0.649527    0.610332  ...    0.587710         0.493046
# NU_NOTA_LC         0.641624    0.744170  ...    1.000000         0.535797
# NU_NOTA_REDACAO    0.504740    0.528338  ...    0.535797         1.000000
#
# [5 rows x 5 columns]

# %%
import numpy as np
mask = np.zeros_like(correlacao)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True, mask=mask)

# %% [markdown]
# Desafio 03: Filtrar as notas por seu estado ou sua cidade e refazer as análises, verificando se são semelhantes ao geral.

# %%
dados_sem_notas_zero_rs = dados_sem_notas_zero.query('SG_UF_RESIDENCIA == "RS"')
dados_sem_notas_zero_rs.head()
# Out:
#        NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 17134  190001684775    2019                  4315602  ...    B     B        1418.4
# 17135  190001684810    2019                  4314902  ...    B     B        3310.4
# 17136  190001684848    2019                  4316907  ...    C     B        3023.4
# 17137  190001684857    2019                  4314407  ...    B     B        2905.4
# 17140  190001684958    2019                  4301859  ...    A     A        2204.4
#
# [5 rows x 137 columns]

# %%
plt.figure(figsize=(12,8))
plt.title('Notas totais Rio Grande do Sul', size=20)
sns.histplot(dados_sem_notas_zero_rs, x = "NU_NOTA_TOTAL")

# %%
plt.figure(figsize=(12,8))
plt.title('Notas de Matemática - Rio Grande do Sul', size=20)
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")

# %%
plt.figure(figsize=(12,8))
plt.title('Notas de Linguagens e códigos - Rio Grande do Sul', size=20)
sns.histplot(dados_sem_notas_zero_rs, x = "NU_NOTA_LC")

# %%
plt.figure(figsize=(12,8))
plt.title('Notas totais com e sem internet - Rio Grande do Sul', size=20)
sns.histplot(dados_sem_notas_zero_rs, x = "NU_NOTA_TOTAL", hue="Q025", kde=True)

# %%
plt.figure(figsize=(12,8))
plt.title('Notas totais com e sem internet - Rio Grande do Sul', size=20)
sns.histplot(dados_sem_notas_zero_rs, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability")

# %%
plt.figure(figsize=(12,8))
plt.title('Notas totais com e sem internet - Rio Grande do Sul', size=20)
sns.histplot(dados_sem_notas_zero_rs, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="density", cumulative=True)

# %%
plt.figure(figsize=(10, 10))
plt.title('Notas totais com e sem internet - Rio Grande do Sul', size=20)
sns.scatterplot(data = dados_sem_notas_zero_rs, x="NU_NOTA_MT", y="NU_NOTA_LC", hue="Q025")
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
sns.pairplot(dados_sem_notas_zero_rs[provas])

# %%
correlacao = dados_sem_notas_zero_rs[provas].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_CH  ...  NU_NOTA_LC  NU_NOTA_REDACAO
# NU_NOTA_CN         1.000000    0.646951  ...    0.631861         0.477776
# NU_NOTA_CH         0.646951    1.000000  ...    0.744852         0.503358
# NU_NOTA_MT         0.625089    0.586951  ...    0.577489         0.472942
# NU_NOTA_LC         0.631861    0.744852  ...    1.000000         0.487272
# NU_NOTA_REDACAO    0.477776    0.503358  ...    0.487272         1.000000
#
# [5 rows x 5 columns]

# %%
plt.title('Mapa de calor - Correlações notas nas diferentes áreas', size=20)
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True)
